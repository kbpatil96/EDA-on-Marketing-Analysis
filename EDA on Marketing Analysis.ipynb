# %%
# Importing all the required libraries.

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset.

df = pd.read_csv('../Dataset of EDA/marketing_data.csv')

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.shape
# Out:
# (2240, 28)

# %%
# View the random sample from dataset 

df.sample(10)
# Out:
#         ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 947   1340        1986  Graduation        Married  $92,910.00         0
# 481   5493        1976  Graduation        Married  $39,356.00         1
# 1519  1502        1983  Graduation       Together  $28,427.00         1
# 1192  4764        1952      Master       Together  $40,442.00         1
# 1301  3340        1977  Graduation        Married  $42,014.00         1
# 909   1458        1982      Master        Married  $21,059.00         1
# 2141  4789        1953  Graduation       Together  $80,812.00         0
# 152   8545        1954  Graduation       Divorced  $85,683.00         0
# 1482  4706        1966  Graduation         Single  $34,704.00         0
# 1984  3332        1985  Graduation         Single  $29,760.00         1
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 947          0     4/24/14       42       551  ...                 13
# ...

# %%
# Analyzing duplicate values

df.duplicated().all()
# Out:
# False

# %%
# Checking the NA values in each columns.

df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
#  Income                24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
# Clean up column names that contain whitespace

df.rename(columns={' Income ':'Income'}, inplace = True)
df['Income']=df['Income'].str.replace("$","",regex = False)

# %%
# Transform Income column to a numerical

df["Income"]=df["Income"].str.replace(",","", regex = False)
df["Income"]=df["Income"].astype(float)

# %%
# Plotting boxplot for checking the outliers.

plt.grid()  
plt.title('Income',size=15)
sns.boxplot(x='Income', data=df)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Income'>

# %%
sns.histplot(df['Income'],kde=False)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %%
#Impute null values in Income, using median value (to avoid skewing of the mean due to outliers):

df['Income']=df['Income'].fillna(df['Income'].median())

# %%
# To convert string Date time into Python Date time object

df['Dt_Customer']=pd.to_datetime(df['Dt_Customer'])

# %%
df['Customer_Age'] = df['Dt_Customer'].dt.year - df['Year_Birth']

# %%
df['Customer_Age']
# Out:
# 0       44
# 1       53
# 2       56
# 3       47
# 4       25
#         ..
# 2235    37
# 2236    36
# 2237    36
# 2238    34
# 2239    43
# Name: Customer_Age, Length: 2240, dtype: int64

# %%
df['Total_Spent']=(df['MntWines']+df['MntFruits']+df['MntMeatProducts']+df['MntFishProducts']+df['MntSweetProducts']+df['MntGoldProds'])
df['Total_Purchases']=(df['NumDealsPurchases']+df['NumWebPurchases']+df['NumCatalogPurchases']+df['NumStorePurchases']+df['NumWebVisitsMonth'])

# %%
df['Total_Spent']
# Out:
# 0       1190
# 1        577
# 2        251
# 3         11
# 4         91
#         ...
# 2235     689
# 2236      55
# 2237     309
# 2238    1383
# 2239    1078
# Name: Total_Spent, Length: 2229, dtype: int64

# %%
df['Total_Purchases']
# Out:
# 0       16
# 1       23
# 2       13
# 3       11
# 4       15
#         ..
# 2235    24
# 2236    13
# 2237    22
# 2238    23
# 2239    25
# Name: Total_Purchases, Length: 2240, dtype: int64

# %%
df['Kids_Teen_at_home'] = df['Kidhome'] + df['Teenhome']

# %%
df['Kids_Teen_at_home']
# Out:
# 0       0
# 1       0
# 2       1
# 3       2
# 4       1
#        ..
# 2235    1
# 2236    1
# 2237    1
# 2238    0
# 2239    2
# Name: Kids_Teen_at_home, Length: 2240, dtype: int64

# %%
# Reducing unnecessary columns

df = df.drop(['ID','Kidhome','Teenhome'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year_Birth           2240 non-null   int64
#  1   Education            2240 non-null   object
#  2   Marital_Status       2240 non-null   object
#  3   Income               2240 non-null   float64
#  4   Dt_Customer          2240 non-null   datetime64[ns]
#  5   Recency              2240 non-null   int64
#  6   MntWines             2240 non-null   int64
#  7   MntFruits            2240 non-null   int64
#  8   MntMeatProducts      2240 non-null   int64
#  9   MntFishProducts      2240 non-null   int64
#  10  MntSweetProducts     2240 non-null   int64
#  11  MntGoldProds         2240 non-null   int64
#  12  NumDealsPurchases    2240 non-null   int64
#  13  NumWebPurchases      2240 non-null   int64
#  14  NumCatalogPurchases  2240 non-null   int64
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe().T
# Out:
#                       count          mean           std     min       25%  \
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2240.0  52237.975446  25037.955891  1730.0  35538.75
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# NumDealsPurchases    2240.0      2.325000      1.932238     0.0      1.00
# NumWebPurchases      2240.0      4.084821      2.778714     0.0      2.00
# NumCatalogPurchases  2240.0      2.662054      2.923101     0.0      0.00
# ...

# %%
# Year of Birth outliers

sns.boxplot(x='Year_Birth', data=df)
# Out:
# <AxesSubplot:xlabel='Year_Birth'>

# %%
# Delete Outliers

df=df[df['Year_Birth']>=1920]

# %%
# Education outliers

plt.grid()
plt.title('Education',size=15)
sns.countplot(x = df['Education'],palette = 'rainbow')
# Out:
# <AxesSubplot:title={'center':'Education'}, xlabel='Education', ylabel='count'>

# %%
# Income outliers

plt.grid()
plt.title('Income',size=15)
sns.boxplot(x='Income', data=df)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Income'>

# %%
sns.histplot(df['Income'],kde=True)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %%
df=df[df['Income']<150000]

# %%
plt.grid()
plt.title('Income',size=15)
sns.histplot(df['Income'],kde=20)
# Out:
# <AxesSubplot:title={'center':'Income'}, xlabel='Income', ylabel='Count'>

# %%
pd.value_counts(df['Kids_Teen_at_home'])
# Out:
# 1    1123
# 0     633
# 2     420
# 3      53
# Name: Kids_Teen_at_home, dtype: int64

# %%
# Plotting kids and teen count at home 

plt.grid()
plt.title('Kids_Teen_at_home',size=15)
sns.countplot(x = df['Kids_Teen_at_home'],palette = 'rocket_r')
# Out:
# <AxesSubplot:title={'center':'Kids_Teen_at_home'}, xlabel='Kids_Teen_at_home', ylabel='count'>

# %%
df1=df.copy()

# %%
sns.set()
df1.set_index('Dt_Customer',inplace=True)
df1.head()
# Out:
#              Year_Birth   Education Marital_Status   Income  Recency  \
# Dt_Customer
# 2014-06-16         1970  Graduation       Divorced  84835.0        0
# 2014-06-15         1961  Graduation         Single  57091.0        0
# 2014-05-13         1958  Graduation        Married  67267.0        0
# 2014-05-11         1967  Graduation       Together  32474.0        0
# 2014-04-08         1989  Graduation         Single  21474.0        0
#
#              MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Dt_Customer
# 2014-06-16        189        104              379              111
# 2014-06-15        464          5               64                7
# 2014-05-13        134         11               59               15
# 2014-05-11         10          0                1                0
# 2014-04-08          6         16               24               11
#
#              MntSweetProducts  ...  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# Dt_Customer                    ...
# ...

# %%
# Plotting total purchase column.

df1[['Total_Purchases']].plot(figsize=(40,10))
# Out:
# <AxesSubplot:xlabel='Dt_Customer'>

# %%
# Plotting total spent column.

df1[['Total_Spent']].plot(figsize=(40,10))
# Out:
# <AxesSubplot:xlabel='Dt_Customer'>

# %%
# Plotting custome age column.

df1[['Customer_Age']].plot(figsize=(40,10))
# Out:
# <AxesSubplot:xlabel='Dt_Customer'>

# %%
# Binning

df['age_bins'] = pd.cut(x=df['Customer_Age'], bins=[1,18,40,80],labels=['Kids','Youngster', 'Adult'])
df['age_bins']
# Out:
# 0           Adult
# 1           Adult
# 2           Adult
# 3           Adult
# 4       Youngster
#           ...
# 2235    Youngster
# 2236    Youngster
# 2237    Youngster
# 2238    Youngster
# 2239        Adult
# Name: age_bins, Length: 2229, dtype: category
# Categories (3, object): ['Kids' < 'Youngster' < 'Adult']

# %%
sns.barplot(x =df['age_bins'],y = df['Year_Birth'],data = df, saturation=10)
plt.show()

# %%
# Marital Status

m = df['Marital_Status'].value_counts().to_frame('Count')
sns.set_palette('rocket_r')
plt.figure(figsize = (6, 6))
plt.pie(m['Count'], labels = m.index, explode = (0.1, 0, 0, 0, 0, 1, 2.5, 4), shadow = True, autopct = '%1.1f%%')
plt.show()
